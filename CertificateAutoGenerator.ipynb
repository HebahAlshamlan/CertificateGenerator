# %% [markdown]
# <a href="https://colab.research.google.com/github/HebahAlshamlan/CertificateGenerator/blob/master/CertificateAutoGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('شهادة متطوعات كسوة فرح ٧.jpg',cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
cv2.circle(img,(1313 ,987), 55, (0,255,0), -1)

plt.imshow(img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'هبه الشملان',(1313 ,987), font, 20, (0,255,0), 20, cv2.LINE_AA)
plt.imshow(img)

# %%
from PIL import ImageFont, ImageDraw, Image  
image = Image.open("شهادة متطوعات كسوة فرح ٧.jpg")  

draw = ImageDraw.Draw(image)  
   
 # use a truetype font  
font = ImageFont.truetype("arial.ttf", 50)  
   
draw.text((1313 ,987), "هلا والله !!", font=font)  
    
plt.imshow(img)

# %%
from PIL import ImageFont, ImageDraw, Image  
import cv2  
import numpy as np  
  
text_to_show = "The quick brown fox jumps over the lazy dog"  
  
# Load image in OpenCV  
image = cv2.imread("شهادة متطوعات كسوة فرح ٧.jpg")  
  
# Convert the image to RGB (OpenCV uses BGR)  
cv2_im_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)  
  
# Pass the image to PIL  
pil_im = Image.fromarray(cv2_im_rgb)  
  
draw = ImageDraw.Draw(pil_im)  
# use a truetype font  
font = ImageFont.truetype("arial.ttf", 80)  
  
# Draw the text  
draw.text((10, 700), text_to_show, font=font)  
  
# Get back the image to OpenCV  
cv2_im_processed = cv2.cvtColor(np.array(pil_im), cv2.COLOR_RGB2BGR)  
  
cv2.imshow('Fonts', cv2_im_processed)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-30-65546fb9ef85> in <module>()
#      24 cv2_im_processed = cv2.cvtColor(np.array(pil_im), cv2.COLOR_RGB2BGR)
#      25
# ---> 26 cv2.imshow(cv2_im_processed)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
